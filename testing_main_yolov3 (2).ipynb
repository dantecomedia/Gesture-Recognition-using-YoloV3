# %%
# !git clone https://github.com/AlexeyAB/darknet.git
# Out:
# Cloning into 'darknet'...
# remote: Enumerating objects: 8, done.
# remote: Counting objects: 100% (8/8), done.
# remote: Compressing objects: 100% (6/6), done.
# remote: Total 13047 (delta 2), reused 6 (delta 2), pack-reused 13039
# Receiving objects: 100% (13047/13047), 11.78 MiB | 13.86 MiB/s, done.
# Resolving deltas: 100% (8915/8915), done.

# %%
# !ls
# Out:
# shell-init: error retrieving current directory: getcwd: cannot access parent directories: No such file or directory

# %%
from google.colab import drive 
drive.mount("/content/gdrive")
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive

# %%
cd /content/darknet
# Out:
# /content/darknet

# %%
# !ls
# Out:
# 3rdparty      cmake		      image_yolov2.sh	     net_cam_v3.sh
# appveyor.yml  CMakeLists.txt	      image_yolov3.sh	     README.md
# build	      DarknetConfig.cmake.in  include		     scripts
# build.ps1     darknet.py	      json_mjpeg_streams.sh  src
# build.sh      darknet_video.py	      LICENSE		     video_v2.sh
# cfg	      data		      Makefile		     video_yolov3.sh

# %%
# !make
# Out:
# mkdir -p ./obj/
# mkdir -p backup
# mkdir -p results
# chmod +x *.sh
# g++ -std=c++11 -std=c++11 -Iinclude/ -I3rdparty/stb/include -DGPU -I/usr/local/cuda/include/ -DCUDNN -DCUDNN_HALF -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DGPU -DCUDNN -I/usr/local/cudnn/include -DCUDNN_HALF -c ./src/image_opencv.cpp -o obj/image_opencv.o
# g++ -std=c++11 -std=c++11 -Iinclude/ -I3rdparty/stb/include -DGPU -I/usr/local/cuda/include/ -DCUDNN -DCUDNN_HALF -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DGPU -DCUDNN -I/usr/local/cudnn/include -DCUDNN_HALF -c ./src/http_stream.cpp -o obj/http_stream.o
# ./src/http_stream.cpp: In member function ‘bool JSON_sender::write(const char*)’:
# ./src/http_stream.cpp:247:21: warning: unused variable ‘n’ [-Wunused-variable]
#                  int n = _write(client, outputbuf, outlen);
#                      ^
# ...

# %%
# !ls
# Out:
# 3rdparty      cmake		      image_yolov2.sh	     obj
# appveyor.yml  CMakeLists.txt	      image_yolov3.sh	     README.md
# backup	      darknet		      include		     results
# build	      DarknetConfig.cmake.in  json_mjpeg_streams.sh  scripts
# build.ps1     darknet.py	      LICENSE		     src
# build.sh      darknet_video.py	      Makefile		     video_v2.sh
# cfg	      data		      net_cam_v3.sh	     video_yolov3.sh

# %%
# !./darknet
# Out:
# usage: ./darknet <function>

# %%
# !wget https://pjreddie.com/media/files/darknet19_448.conv.23
# Out:
# --2020-04-12 19:20:45--  https://pjreddie.com/media/files/darknet19_448.conv.23
# Resolving pjreddie.com (pjreddie.com)... 128.208.4.108
# Connecting to pjreddie.com (pjreddie.com)|128.208.4.108|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 79327120 (76M) [application/octet-stream]
# Saving to: ‘darknet19_448.conv.23’
#
# darknet19_448.conv. 100%[===================>]  75.65M  7.38MB/s    in 10s
#
# 2020-04-12 19:20:55 (7.52 MB/s) - ‘darknet19_448.conv.23’ saved [79327120/79327120]

# %%
# !cp "/content/gdrive/My Drive/Image file for gesture research/gesture_4.zip" /content

# %%
import os 
os.mkdir("/content/images")

# %%
import shutil
shutil.rmtree("/content/darknet/images")

# %%
# !unzip /content/gesture_4.zip -d /content/images
# Out:
# Archive:  /content/gesture_4.zip
#    creating: /content/images/gesture_4/
#   inflating: /content/images/gesture_4/frame_09_03_0192.txt
#   inflating: /content/images/gesture_4/frame_09_03_0191.txt
#   inflating: /content/images/gesture_4/frame_09_03_0190.txt
#   inflating: /content/images/gesture_4/frame_09_03_0189.txt
#   inflating: /content/images/gesture_4/frame_09_03_0188.txt
#   inflating: /content/images/gesture_4/frame_09_03_0187.txt
#   inflating: /content/images/gesture_4/frame_09_03_0186.txt
#   inflating: /content/images/gesture_4/frame_09_03_0184.txt
#   inflating: /content/images/gesture_4/frame_09_03_0183.txt
#   inflating: /content/images/gesture_4/frame_09_03_0182.txt
#   inflating: /content/images/gesture_4/frame_09_03_0181.txt
#   inflating: /content/images/gesture_4/frame_09_03_0180.txt
#   inflating: /content/images/gesture_4/frame_09_03_0179.txt
#   inflating: /content/images/gesture_4/frame_09_03_0178.txt
# ...

# %%
# !mv "/content/images/images" "/content/darknet"

# %%
os.rmdir("/content/images")

# %%
# !ls
# Out:
# 3rdparty      CMakeLists.txt	      image_yolov2.sh	     README.md
# appveyor.yml  darknet		      image_yolov3.sh	     results
# backup	      darknet19_448.conv.23   include		     scripts
# build	      DarknetConfig.cmake.in  json_mjpeg_streams.sh  src
# build.ps1     darknet.py	      LICENSE		     video_v2.sh
# build.sh      darknet_video.py	      Makefile		     video_yolov3.sh
# cfg	      data		      net_cam_v3.sh
# cmake	      images		      obj

# %%
# !./darknet
# Out:
# usage: ./darknet <function>

# %%
cd cfg
# Out:
# /content/darknet/cfg

# %%
ls
# Out:
# 9k.labels                                   resnet101.cfg
# 9k.names                                    resnet152.cfg
# 9k.tree                                     resnet152_trident.cfg
# alexnet.cfg                                 resnet50.cfg
# cd53paspp-gamma.cfg                         resnext152-32x4d.cfg
# cd53paspp-omega.cfg                         rnn.cfg
# cifar.cfg                                   rnn.train.cfg
# cifar.test.cfg                              strided.cfg
# coco9k.map                                  t1.test.cfg
# coco.data                                   tiny.cfg
# coco.names                                  tiny-yolo.cfg
# combine9k.data                              tiny-yolo-voc.cfg
# crnn.train.cfg                              tiny-yolo_xnor.cfg
# csdarknet53-omega.cfg                       vgg-16.cfg
# csresnext50-panet-spp.cfg                   vgg-conv.cfg
# csresnext50-panet-spp-original-optimal.cfg  voc.data
# ...

# %%
# !mv /content/yolo-voc.2.0.cfg /content/darknet/cfg/

# %%
# !./darknet detector train cfg/obj.data cfg/yolo-voc.2.0.cfg darknet19_448.conv.23 -dont_show 0
# Out:
#  CUDA-version: 10010 (10010), cuDNN: 7.6.5, CUDNN_HALF=1, GPU count: 1
#  CUDNN_HALF=1
#  OpenCV isn't used - data increase will run slowly
# yolo-voc
#  compute_capability = 610, cudnn_half = 0
# net.optimized_memory = 0
# mini_batch = 8, batch = 64, time_steps = 1, train = 1
#    layer   filters  size/strd(dil)      input                output
#    0
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-62-af553abcb963> in <module>()
# ----> 1 get_ipython().system('./darknet detector train cfg/obj.data cfg/yolo-voc.2.0.cfg darknet19_448.conv.23 -dont_show 0')
#
# /usr/local/lib/python3.6/dist-packages/google/colab/_shell.py in system(self, *args, **kwargs)
#      94       kwargs.update({'also_return_output': True})
#      95
# ---> 96     output = _system_commands._system_compat(self, *args, **kwargs)  # pylint:disable=protected-access
#      97
# ...

# %%
# !mv /content/test.txt /content/darknet/

# %%
# !./darknet --help
# Out:
#  CUDA-version: 10010 (10010), cuDNN: 7.6.5, CUDNN_HALF=1, GPU count: 1
#  CUDNN_HALF=1
#  OpenCV isn't used - data increase will run slowly
# Not an option: --help

# %%
#download files
def imShow(path):
  import cv2
  import matplotlib.pyplot as plt
  # %matplotlib inline

  image = cv2.imread(path)
  height, width = image.shape[:2]
  resized_image = cv2.resize(image,(3*width, 3*height), interpolation = cv2.INTER_CUBIC)

  fig = plt.gcf()
  fig.set_size_inches(18, 10)
  plt.axis("off")
  #plt.rcParams['figure.figsize'] = [10, 5]
  plt.imshow(cv2.cvtColor(resized_image, cv2.COLOR_BGR2RGB))
  plt.show()
  
  
def upload():
  from google.colab import files
  uploaded = files.upload() 
  for name, data in uploaded.items():
    with open(name, 'wb') as f:
      f.write(data)
      print ('saved file', name)
def download(path):
  from google.colab import files
  files.download(path)

# %%
# Not necessary cell
# Execute darknet using YOLOv3 model with pre-trained weights to detect objects on 'person.jpg'
# !./darknet detect cfg/yolo-voc.2.0.cfg /content/darknet/backup/yolo-voc_1000.weights /content/frame_09_02_0129.png -dont-show

# Show the result using the helper imgShow()
imShow('predictions.jpg')
# Out:
#  CUDA-version: 10010 (10010), cuDNN: 7.6.5, CUDNN_HALF=1, GPU count: 1
#  CUDNN_HALF=1
#  OpenCV isn't used - data increase will run slowly
#  compute_capability = 610, cudnn_half = 0
# net.optimized_memory = 0
# mini_batch = 1, batch = 8, time_steps = 1, train = 0
#    layer   filters  size/strd(dil)      input                output
#    0 conv     32       3 x 3/ 1    416 x 416 x   3 ->  416 x 416 x  32 0.299 BF
#    1 max                2x 2/ 2    416 x 416 x  32 ->  208 x 208 x  32 0.006 BF
#    2 conv     64       3 x 3/ 1    208 x 208 x  32 ->  208 x 208 x  64 1.595 BF
#    3 max                2x 2/ 2    208 x 208 x  64 ->  104 x 104 x  64 0.003 BF
#    4 conv    128       3 x 3/ 1    104 x 104 x  64 ->  104 x 104 x 128 1.595 BF
#    5 conv     64       1 x 1/ 1    104 x 104 x 128 ->  104 x 104 x  64 0.177 BF
#    6 conv    128       3 x 3/ 1    104 x 104 x  64 ->  104 x 104 x 128 1.595 BF
#    7 max                2x 2/ 2    104 x 104 x 128 ->   52 x  52 x 128 0.001 BF
# ...

# %%
# Not necessary cell
# Execute darknet using YOLOv3 model with pre-trained weights to detect objects on 'person.jpg'
# !./darknet detect cfg/yolo-voc.2.0.cfg /content/darknet/backup/yolo-voc_1000.weights /content/frame_08_03_0096.png -dont-show

# Show the result using the helper imgShow()
imShow('predictions.jpg')
# Out:
#  CUDA-version: 10010 (10010), cuDNN: 7.6.5, CUDNN_HALF=1, GPU count: 1
#  CUDNN_HALF=1
#  OpenCV isn't used - data increase will run slowly
#  compute_capability = 610, cudnn_half = 0
# net.optimized_memory = 0
# mini_batch = 1, batch = 8, time_steps = 1, train = 0
#    layer   filters  size/strd(dil)      input                output
#    0 conv     32       3 x 3/ 1    416 x 416 x   3 ->  416 x 416 x  32 0.299 BF
#    1 max                2x 2/ 2    416 x 416 x  32 ->  208 x 208 x  32 0.006 BF
#    2 conv     64       3 x 3/ 1    208 x 208 x  32 ->  208 x 208 x  64 1.595 BF
#    3 max                2x 2/ 2    208 x 208 x  64 ->  104 x 104 x  64 0.003 BF
#    4 conv    128       3 x 3/ 1    104 x 104 x  64 ->  104 x 104 x 128 1.595 BF
#    5 conv     64       1 x 1/ 1    104 x 104 x 128 ->  104 x 104 x  64 0.177 BF
#    6 conv    128       3 x 3/ 1    104 x 104 x  64 ->  104 x 104 x 128 1.595 BF
#    7 max                2x 2/ 2    104 x 104 x 128 ->   52 x  52 x 128 0.001 BF
# ...

# %%
# Not necessary cell
# Execute darknet using YOLOv3 model with pre-trained weights to detect objects on 'person.jpg'
# !./darknet detect cfg/yolo-voc.2.0.cfg /content/darknet/backup/yolo-voc_1000.weights /content/frame_09_04_0174.png -dont-show

# Show the result using the helper imgShow()
imShow('predictions.jpg')
# Out:
#  CUDA-version: 10010 (10010), cuDNN: 7.6.5, CUDNN_HALF=1, GPU count: 1
#  CUDNN_HALF=1
#  OpenCV isn't used - data increase will run slowly
#  compute_capability = 610, cudnn_half = 0
# net.optimized_memory = 0
# mini_batch = 1, batch = 8, time_steps = 1, train = 0
#    layer   filters  size/strd(dil)      input                output
#    0 conv     32       3 x 3/ 1    416 x 416 x   3 ->  416 x 416 x  32 0.299 BF
#    1 max                2x 2/ 2    416 x 416 x  32 ->  208 x 208 x  32 0.006 BF
#    2 conv     64       3 x 3/ 1    208 x 208 x  32 ->  208 x 208 x  64 1.595 BF
#    3 max                2x 2/ 2    208 x 208 x  64 ->  104 x 104 x  64 0.003 BF
#    4 conv    128       3 x 3/ 1    104 x 104 x  64 ->  104 x 104 x 128 1.595 BF
#    5 conv     64       1 x 1/ 1    104 x 104 x 128 ->  104 x 104 x  64 0.177 BF
#    6 conv    128       3 x 3/ 1    104 x 104 x  64 ->  104 x 104 x 128 1.595 BF
#    7 max                2x 2/ 2    104 x 104 x 128 ->   52 x  52 x 128 0.001 BF
# ...

# %%
# Not necessary cell
# Execute darknet using YOLOv3 model with pre-trained weights to detect objects on 'person.jpg'
# !./darknet detect cfg/yolo-voc.2.0.cfg /content/darknet/backup/yolo-voc_1000.weights /content/frame_08_03_0094.png -dont-show

# Show the result using the helper imgShow()
imShow('predictions.jpg')
# Out:
#  CUDA-version: 10010 (10010), cuDNN: 7.6.5, CUDNN_HALF=1, GPU count: 1
#  CUDNN_HALF=1
#  OpenCV isn't used - data increase will run slowly
#  compute_capability = 610, cudnn_half = 0
# net.optimized_memory = 0
# mini_batch = 1, batch = 8, time_steps = 1, train = 0
#    layer   filters  size/strd(dil)      input                output
#    0 conv     32       3 x 3/ 1    416 x 416 x   3 ->  416 x 416 x  32 0.299 BF
#    1 max                2x 2/ 2    416 x 416 x  32 ->  208 x 208 x  32 0.006 BF
#    2 conv     64       3 x 3/ 1    208 x 208 x  32 ->  208 x 208 x  64 1.595 BF
#    3 max                2x 2/ 2    208 x 208 x  64 ->  104 x 104 x  64 0.003 BF
#    4 conv    128       3 x 3/ 1    104 x 104 x  64 ->  104 x 104 x 128 1.595 BF
#    5 conv     64       1 x 1/ 1    104 x 104 x 128 ->  104 x 104 x  64 0.177 BF
#    6 conv    128       3 x 3/ 1    104 x 104 x  64 ->  104 x 104 x 128 1.595 BF
#    7 max                2x 2/ 2    104 x 104 x 128 ->   52 x  52 x 128 0.001 BF
# ...

# %%
# Not necessary cell
# Execute darknet using YOLOv3 model with pre-trained weights to detect objects on 'person.jpg'
# !./darknet detect cfg/yolo-voc.2.0.cfg /content/darknet/backup/yolo-voc_1000.weights /content/frame_09_09_0098.png -dont-show

# Show the result using the helper imgShow()
imShow('predictions.jpg')
# Out:
#  CUDA-version: 10010 (10010), cuDNN: 7.6.5, CUDNN_HALF=1, GPU count: 1
#  CUDNN_HALF=1
#  OpenCV isn't used - data increase will run slowly
#  compute_capability = 610, cudnn_half = 0
# net.optimized_memory = 0
# mini_batch = 1, batch = 8, time_steps = 1, train = 0
#    layer   filters  size/strd(dil)      input                output
#    0 conv     32       3 x 3/ 1    416 x 416 x   3 ->  416 x 416 x  32 0.299 BF
#    1 max                2x 2/ 2    416 x 416 x  32 ->  208 x 208 x  32 0.006 BF
#    2 conv     64       3 x 3/ 1    208 x 208 x  32 ->  208 x 208 x  64 1.595 BF
#    3 max                2x 2/ 2    208 x 208 x  64 ->  104 x 104 x  64 0.003 BF
#    4 conv    128       3 x 3/ 1    104 x 104 x  64 ->  104 x 104 x 128 1.595 BF
#    5 conv     64       1 x 1/ 1    104 x 104 x 128 ->  104 x 104 x  64 0.177 BF
#    6 conv    128       3 x 3/ 1    104 x 104 x  64 ->  104 x 104 x 128 1.595 BF
#    7 max                2x 2/ 2    104 x 104 x 128 ->   52 x  52 x 128 0.001 BF
# ...
